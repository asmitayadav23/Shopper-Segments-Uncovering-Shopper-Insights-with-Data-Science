# %% [markdown]
# # Importing modules

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %% [markdown]
# # Collecting data from csv file

# %%
os.listdir(r'C:\Users\91995\OneDrive\Desktop\Data Analytics\My Project')
# Out:
# ['ML_Supermarket_sales_deploy.ipynb', 'supermarket_sales - Sheet1.csv']

# %%
data = pd.read_csv(r'C:\Users\91995\OneDrive\Desktop\Data Analytics\My Project/supermarket_sales - Sheet1.csv')

# %% [markdown]
# # Data Analysis

# %%
data.head(5)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
data.shape
# Out:
# (1000, 17)

# %%
data.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Invoice ID                  object
# Branch                      object
# City                        object
# Customer type               object
# Gender                      object
# Product line                object
# Unit price                 float64
# Quantity                     int64
# Tax 5%                     float64
# Total                      float64
# Date                        object
# Time                        object
# Payment                     object
# cogs                       float64
# gross margin percentage    float64
# gross income               float64
# Rating                     float64
# dtype: object

# %%
data['Date'] = pd.to_datetime(data['Date'])

# %%
data.dtypes
# Out:
# Invoice ID                         object
# Branch                             object
# City                               object
# Customer type                      object
# Gender                             object
# Product line                       object
# Unit price                        float64
# Quantity                            int64
# Tax 5%                            float64
# Total                             float64
# Date                       datetime64[ns]
# Time                               object
# Payment                            object
# cogs                              float64
# gross margin percentage           float64
# gross income                      float64
# Rating                            float64
# dtype: object

# %%
data['Time'] = pd.to_datetime(data['Time'])
# Out:
# C:\Users\91995\AppData\Local\Temp\ipykernel_6644\3567905165.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data['Time'] = pd.to_datetime(data['Time'])

# %%
data.dtypes
# Out:
# Invoice ID                         object
# Branch                             object
# City                               object
# Customer type                      object
# Gender                             object
# Product line                       object
# Unit price                        float64
# Quantity                            int64
# Tax 5%                            float64
# Total                             float64
# Date                       datetime64[ns]
# Time                       datetime64[ns]
# Payment                            object
# cogs                              float64
# gross margin percentage           float64
# gross income                      float64
# Rating                            float64
# dtype: object

# %%
data['Date'][1]
# Out:
# Timestamp('2019-03-08 00:00:00')

# %%
data['Day'] = data['Date'].dt.day

# %%
data.head(2)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715 2019-01-05
# 1  Electronic accessories       15.28         5   3.8200   80.2200 2019-03-08
#
#                  Time  Payment    cogs  gross margin percentage  gross income  \
# 0 2025-01-07 13:08:00  Ewallet  522.83                 4.761905       26.1415
# 1 2025-01-07 10:29:00     Cash   76.40                 4.761905        3.8200
#
#    Rating  Day
# 0     9.1    5
# 1     9.6    8

# %%
data['Month'] = data['Date'].dt.month
data['Year'] = data['Date'].dt.year

# %%
data['Hour'] = data['Time'].dt.hour

# %%
data.head(3)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total  ...  \
# 0       Health and beauty       74.69         7  26.1415  548.9715  ...
# 1  Electronic accessories       15.28         5   3.8200   80.2200  ...
# 2      Home and lifestyle       46.33         7  16.2155  340.5255  ...
#
#                  Time      Payment    cogs  gross margin percentage  \
# 0 2025-01-07 13:08:00      Ewallet  522.83                 4.761905
# 1 2025-01-07 10:29:00         Cash   76.40                 4.761905
# 2 2025-01-07 13:23:00  Credit card  324.31                 4.761905
#
#    gross income  Rating  Day  Month  Year  Hour
# 0       26.1415     9.1    5      1  2019    13
# 1        3.8200     9.6    8      3  2019    10
# ...

# %%
data.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total  \
# count  1000.000000  1000.000000  1000.000000  1000.000000
# mean     55.672130     5.510000    15.379369   322.966749
# min      10.080000     1.000000     0.508500    10.678500
# 25%      32.875000     3.000000     5.924875   124.422375
# 50%      55.230000     5.000000    12.088000   253.848000
# 75%      77.935000     8.000000    22.445250   471.350250
# max      99.960000    10.000000    49.650000  1042.650000
# std      26.494628     2.923431    11.708825   245.885335
#
#                              Date                        Time        cogs  \
# count                        1000                        1000  1000.00000
# mean   2019-02-14 00:05:45.600000  2025-01-07 15:24:41.880000   307.58738
# min           2019-01-01 00:00:00         2025-01-07 10:00:00    10.17000
# 25%           2019-01-24 00:00:00         2025-01-07 12:43:00   118.49750
# ...

# %% [markdown]
# # Finding co-relation values of a matrix

# %%
numeric_data = data.select_dtypes(include=[np.number])  # Select only numeric columns
correlation_matrix = numeric_data.corr()  # Compute correlation matrix
plt.figure(figsize = (12,6))
sns.heatmap(np.round(correlation_matrix,2),annot = True)
plt.show()

# %%
sns.regplot(x='Quantity', y = 'cogs', data = data, color = 'green')
plt.xlabel('Quantity')
plt.ylabel('Cost Of Good Sales')
plt.show()

# %%
sns.regplot(x= 'Tax 5%', y = 'gross income', data = data, color = 'green')
plt.xlabel('Tax')
plt.ylabel('Gross Income')
plt.show()

# %%
np.mean(data['Rating'])
# Out:
# 6.9727

# %%
new_col = []
for col in data.columns:
    if data[col].dtype == 'object':
        new_col.append(col)
print(new_col)
# Out:
# ['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender', 'Product line', 'Payment']

# %%
print(data['Branch'].unique())
# Out:
# ['A' 'C' 'B']

# %%
sns.boxplot(x = 'Branch',y = 'Rating', hue = 'Gender', data = data)
plt.title('Rating distribution of every branch')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# B branch has the lowest rating

# %%
sns.lineplot(x='Hour', y= 'Quantity', data = data)
plt.show()

# %% [markdown]
# 14th hour has highest quantity sold.

# %%
data.head(2)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
#
#              Product line  Unit price  Quantity   Tax 5%     Total  ...  \
# 0       Health and beauty       74.69         7  26.1415  548.9715  ...
# 1  Electronic accessories       15.28         5   3.8200   80.2200  ...
#
#                  Time  Payment    cogs  gross margin percentage  gross income  \
# 0 2025-01-07 13:08:00  Ewallet  522.83                 4.761905       26.1415
# 1 2025-01-07 10:29:00     Cash   76.40                 4.761905        3.8200
#
#    Rating  Day  Month  Year  Hour
# 0     9.1    5      1  2019    13
# 1     9.6    8      3  2019    10
#
# [2 rows x 21 columns]

# %%
sns.relplot(x='Hour', y='Quantity', col='Month', row='Branch', kind='line', hue='Gender', data=data)
plt.title('Branch sales in monthly fashion')
plt.show()

# %%
data.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating', 'Day', 'Month', 'Year', 'Hour'],
#       dtype='object')

# %%
plt.figure(figsize = (30,12))
sns.relplot(x='Hour', y = 'Quantity', col = 'Product line', row = 'Branch', kind = 'line', data = data)
plt.show()

# %%
plt.figure(figsize = (6,3))
sns.boxplot(x = 'Quantity',y = 'Product line', data = data)
# Out:
# <Axes: xlabel='Quantity', ylabel='Product line'>

# %% [markdown]
# # Finding relationship in data

# %%
data['Product line'].unique()
# Out:
# array(['Health and beauty', 'Electronic accessories',
#        'Home and lifestyle', 'Sports and travel', 'Food and beverages',
#        'Fashion accessories'], dtype=object)

# %% [markdown]
# Health and beauty, Electronic accessories, Home and lifestyle, Sports and travel has better average quantity than Sports and travel,
# Food and beverages, Fashion accessories

# %%
data.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating', 'Day', 'Month', 'Year', 'Hour'],
#       dtype='object')

# %%
sns.relplot(x = 'gross income', y = 'Product line', kind = 'scatter', data = data)
plt.show()

# %%
sns.countplot(x='Payment', data = data)
plt.show()

# %% [markdown]
# Most customers pay through Ewallet and Cash Payment

# %%
sns.countplot(x='Payment', hue = 'Branch', data = data)
plt.legend(loc = 'lower right')
plt.show()

# %% [markdown]
# Most customer pay through Ewallet in Branch A
# Most customer pay through Ewallet in Branch B
# Most customer pay through Cash Payment in Branch C

# %%
sns.countplot(x = 'Customer type', hue = 'Branch', data = data)
plt.show()

# %% [markdown]
# Most of the Normal in Customer type belongs to Branch A

# %%
data.groupby(['Customer type'])['Total'].sum()
# Out:
# Customer type
# Member    164223.444
# Normal    158743.305
# Name: Total, dtype: float64

# %%
sns.swarmplot(x='Customer type', y = 'Rating', hue = 'City', data = data)
plt.title('Customer type and Rating relation')
plt.legend(loc = 'lower right')
plt.show()

# %%
pip install wordcloud
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
str = '  '.join(data['Product line'])
print(str)
# Out:
# Health and beauty  Electronic accessories  Home and lifestyle  Health and beauty  Sports and travel  Electronic accessories  Electronic accessories  Home and lifestyle  Health and beauty  Food and beverages  Fashion accessories  Electronic accessories  Electronic accessories  Food and beverages  Health and beauty  Sports and travel  Health and beauty  Sports and travel  Food and beverages  Home and lifestyle  Electronic accessories  Health and beauty  Home and lifestyle  Electronic accessories  Sports and travel  Home and lifestyle  Fashion accessories  Fashion accessories  Food and beverages  Health and beauty  Fashion accessories  Sports and travel  Sports and travel  Health and beauty  Food and beverages  Sports and travel  Sports and travel  Electronic accessories  Health and beauty  Home and lifestyle  Home and lifestyle  Home and lifestyle  Sports and travel  Food and beverages  Health and beauty  Electronic accessories  Health and beauty  Food and beverages  Electronic accesso
# ...

# %%
from wordcloud import WordCloud

# %%
data['Product line'].unique()
# Out:
# array(['Health and beauty', 'Electronic accessories',
#        'Home and lifestyle', 'Sports and travel', 'Food and beverages',
#        'Fashion accessories'], dtype=object)

# %%
plt.figure(figsize = (15,8))
wordcloud = WordCloud(width = 1920, height = 1080).generate(str)
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %% [markdown]
# # Building ML Model

# %%
data.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating', 'Day', 'Month', 'Year', 'Hour'],
#       dtype='object')

# %%
X = data['cogs'].values.reshape(-1,1)
print(X)
# Out:
# [[522.83]
#  [ 76.4 ]
#  [324.31]
#  [465.76]
#  [604.17]
#  [597.73]
#  [413.04]
#  [735.6 ]
#  [ 72.52]
#  [164.52]
#  [ 57.92]
#  [102.04]
#  [234.75]
#  [431.9 ]
#  [713.8 ]
#  [562.32]
#  [482.51]
#  [435.66]
#  [164.01]
#  [ 80.6 ]
#  [430.2 ]
#  [263.94]
#  [ 66.4 ]
#  [172.8 ]
#  [265.89]
#  [420.72]
#  [ 33.52]
#  [175.34]
#  [441.8 ]
#  [224.01]
#  [470.65]
#  [702.63]
#  [670.24]
#  [193.16]
#  [397.68]
#  [ 68.12]
#  [313.1 ]
#  [547.92]
#  [439.36]
#  [240.96]
#  [ 86.72]
#  [112.22]
#  [414.72]
#  [789.6 ]
#  [ 30.74]
#  [375.84]
#  [510.21]
#  [180.09]
#  [113.58]
#  [826.3 ]
#  [639.8 ]
#  [222.95]
#  [ 71.48]
#  [ 15.43]
#  [ 32.32]
#  [687.84]
#  [ 88.68]
#  [716.8 ]
#  [723.5 ]
#  [183.66]
#  [ 74.22]
#  [334.38]
#  [495.63]
#  [158.1 ]
#  [302.96]
#  [158.7 ]
#  [ 66.94]
#  [585.66]
#  [787.7 ]
#  [ 18.33]
#  [894.8 ]
#  [621.2 ]
#  [145.56]
#  [455.46]
#  [672.03]
#  [416.5 ]
#  [441.36]
#  [180.09]
#  [783.1 ]
#  [101.9 ]
#  [595.14]
#  [290.04]
#  [154.  ]
# ...

# %%
pip install scikit-learn
# Out:
# ...
#   Obtaining dependency information for scikit-learn from https://files.pythonhosted.org/packages/21/1d/3df58df8bd425f425df9f90b316618ace62b7f1f838ac1580191025cc735/scikit_learn-1.6.0-cp312-cp312-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for scipy>=1.6.0 from https://files.pythonhosted.org/packages/3f/39/a29b75f9c30084cbafd416bfa00933311a5b7a96be6e88750c98521d2ccb/scipy-1.15.0-cp312-cp312-win_amd64.whl.metadata
# ...
#      ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/60.8 kB ? eta -:--:--
#      ------------------------- ------------ 41.0/60.8 kB 487.6 kB/s eta 0:00:01
#      -------------------------------------- 60.8/60.8 kB 647.7 kB/s eta 0:00:00
# ...
#   Obtaining dependency information for joblib>=1.2.0 from https://files.pythonhosted.org/packages/91/29/df4b9b42f2be0b623cbd5e2140cafcaa2bef0759a00b7b70104dcfe2fb51/joblib-1.4.2-py3-none-any.whl.metadata
# ...

# %%
from sklearn.cluster import KMeans

# %%
wcss = []
for i in range(1,11):
    kmeans = KMeans(n_clusters = i, random_state = 42)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)

# %%
wcss
# Out:
# [54783799.02013558,
#  14794351.065176785,
#  6684217.387064209,
#  3886534.5074129114,
#  2614228.8119408097,
#  1771690.801564237,
#  1352643.8364068398,
#  1184649.9424961726,
#  831638.4335130802,
#  691317.4717417229]

# %%
plt.figure(figsize = (12,7))
plt.plot(range(1,11),wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.show()

# %% [markdown]
# When number of cluster = 5 we dont have much inertia thus considering 5 we will initialize kmeans model.

# %%
kmeans = KMeans(n_clusters = 5, random_state = 42)
y_kmeans = kmeans.fit_predict(X)

# %%
y_kmeans
# Out:
# array([3, 2, 0, 0, 3, 3, 0, 1, 2, 4, 2, 2, 4, 0, 1, 3, 3, 0, 4, 2, 0, 4,
#        2, 4, 4, 0, 2, 4, 0, 4, 0, 1, 3, 4, 0, 2, 0, 3, 0, 4, 2, 2, 0, 1,
#        2, 0, 3, 4, 2, 1, 3, 4, 2, 2, 2, 1, 2, 1, 1, 4, 2, 0, 3, 4, 0, 4,
#        2, 3, 1, 2, 1, 3, 2, 0, 3, 0, 0, 4, 1, 2, 3, 4, 4, 0, 4, 3, 0, 0,
#        2, 0, 4, 0, 4, 3, 2, 2, 1, 2, 4, 3, 2, 1, 4, 0, 4, 1, 4, 0, 0, 1,
#        2, 4, 3, 3, 1, 2, 2, 2, 2, 2, 1, 0, 1, 3, 0, 3, 4, 4, 3, 1, 4, 3,
#        2, 3, 3, 4, 2, 4, 3, 3, 1, 1, 1, 2, 0, 4, 0, 4, 3, 4, 0, 4, 1, 2,
#        3, 0, 2, 4, 1, 3, 0, 2, 0, 4, 0, 0, 1, 1, 0, 3, 0, 0, 4, 0, 4, 0,
#        4, 4, 0, 4, 0, 0, 4, 4, 2, 2, 1, 4, 2, 4, 4, 2, 1, 2, 4, 2, 2, 2,
#        4, 0, 2, 4, 0, 4, 2, 4, 3, 4, 2, 1, 4, 1, 0, 2, 4, 2, 2, 4, 1, 4,
#        4, 0, 2, 2, 2, 4, 3, 2, 3, 3, 4, 2, 1, 4, 3, 4, 2, 4, 2, 2, 4, 2,
#        4, 4, 1, 0, 4, 2, 0, 3, 0, 0, 2, 2, 0, 2, 2, 4, 2, 4, 3, 2, 4, 4,
#        2, 1, 2, 1, 4, 0, 0, 2, 4, 2, 3, 0, 4, 0, 1, 0, 3, 2, 2, 3, 4, 0,
# ...
